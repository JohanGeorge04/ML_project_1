# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df=pd.read_csv("diabetes_dataset.csv")

# %%
df.T
# Out:
#                                            0            1           2      \
# age                                           58           48          60
# gender                                      Male       Female        Male
# ethnicity                                  Asian        White    Hispanic
# education_level                       Highschool   Highschool  Highschool
# income_level                        Lower-Middle       Middle      Middle
# employment_status                       Employed     Employed  Unemployed
# smoking_status                             Never       Former       Never
# alcohol_consumption_per_week                   0            1           1
# physical_activity_minutes_per_week           215          143          57
# diet_score                                   5.7          6.7         6.4
# sleep_hours_per_day                          7.9          6.5        10.0
# screen_time_hours_per_day                    7.9          8.7         8.1
# family_history_diabetes                        0            0           1
# hypertension_history                           0            0           0
# cardiovascular_history                         0            0           0
# bmi                                         30.5         23.1        22.2
# waist_to_hip_ratio                          0.89          0.8        0.81
# systolic_bp                                  134          129         115
# diastolic_bp                                  78           76          73
# heart_rate                                    68           67          74
# cholesterol_total                            239          116         213
# hdl_cholesterol                               41           55          66
# ldl_cholesterol                              160           50          99
# triglycerides                                145           30          36
# glucose_fasting                              136           93         118
# glucose_postprandial                         236          150         195
# insulin_level                               6.36          2.0        5.07
# hba1c                                       8.18         5.63        7.51
# diabetes_risk_score                         29.6         23.0        44.7
# diabetes_stage                            Type 2  No Diabetes      Type 2
# diagnosed_diabetes                             1            0           1
#
#                                          3         4             5      \
# age                                         74        46            46
# gender                                  Female      Male        Female
# ethnicity                                Black     White         White
# education_level                     Highschool  Graduate    Highschool
# income_level                               Low    Middle  Upper-Middle
# employment_status                      Retired   Retired      Employed
# smoking_status                           Never     Never         Never
# alcohol_consumption_per_week                 0         1             2
# physical_activity_minutes_per_week          49       109           124
# diet_score                                 3.4       7.2           9.0
# sleep_hours_per_day                        6.6       7.4           6.2
# screen_time_hours_per_day                  5.2       5.0           5.4
# family_history_diabetes                      0         0             0
# hypertension_history                         0         0             0
# cardiovascular_history                       0         0             0
# bmi                                       26.8      21.2          26.1
# waist_to_hip_ratio                        0.88      0.78          0.85
# systolic_bp                                120        92            95
# diastolic_bp                                93        67            81
# heart_rate                                  68        67            57
# cholesterol_total                          171       210           218
# hdl_cholesterol                             50        52            61
# ldl_cholesterol                             79       125           119
# triglycerides                              140       160           179
# glucose_fasting                            139       137           100
# glucose_postprandial                       253       184           133
# insulin_level                             5.28     12.74          8.77
# hba1c                                     9.03       7.2          6.03
# diabetes_risk_score                       38.2      23.5          23.5
# diabetes_stage                          Type 2    Type 2  Pre-Diabetes
# diagnosed_diabetes                           1         1             0
#
#                                            6             7             8      \
# age                                           75            62            42
# gender                                    Female          Male          Male
# ethnicity                                  White         White         Black
# education_level                         Graduate  Postgraduate    Highschool
# income_level                        Upper-Middle        Middle  Lower-Middle
# employment_status                        Retired    Unemployed      Employed
# smoking_status                             Never       Current       Current
# alcohol_consumption_per_week                   0             1             1
# physical_activity_minutes_per_week            53            75           114
# diet_score                                   9.2           4.1           6.7
# sleep_hours_per_day                          7.8           9.0           8.5
# screen_time_hours_per_day                    8.0          12.9           8.5
# family_history_diabetes                        0             0             0
# hypertension_history                           1             1             0
# cardiovascular_history                         0             1             1
# bmi                                         25.1          23.9          24.7
# waist_to_hip_ratio                          0.88          0.86          0.84
# systolic_bp                                  129           128           103
# diastolic_bp                                  77            83            71
# heart_rate                                    81            76            72
# cholesterol_total                            238           241           187
# hdl_cholesterol                               46            49            33
# ldl_cholesterol                              161           159           132
# triglycerides                                155           120            98
# glucose_fasting                              101           110           116
# glucose_postprandial                         100           189           172
# insulin_level                              10.14          8.96           5.7
# hba1c                                       5.24          7.04           6.9
# diabetes_risk_score                         36.1          34.2          26.7
# diabetes_stage                      Pre-Diabetes        Type 2        Type 2
# diagnosed_diabetes                             0             1             1
#
#                                           9      ...       99990       99991  \
# age                                          59  ...          60          63
# gender                                   Female  ...      Female      Female
# ethnicity                                 White  ...       White       White
# education_level                        Graduate  ...  Highschool  Highschool
# income_level                             Middle  ...         Low      Middle
# employment_status                      Employed  ...     Retired  Unemployed
# smoking_status                          Current  ...       Never       Never
# alcohol_consumption_per_week                  3  ...           1           4
# physical_activity_minutes_per_week           86  ...         243          65
# diet_score                                  8.2  ...         6.6         4.0
# sleep_hours_per_day                         5.3  ...         4.8         6.8
# screen_time_hours_per_day                   7.4  ...         4.7         9.8
# family_history_diabetes                       0  ...           0           0
# hypertension_history                          0  ...           0           0
# cardiovascular_history                        0  ...           0           0
# bmi                                        26.7  ...        26.3        30.6
# waist_to_hip_ratio                         0.81  ...        0.87        0.88
# systolic_bp                                 124  ...         128         125
# diastolic_bp                                 81  ...          88          86
# heart_rate                                   70  ...          61          75
# cholesterol_total                           188  ...         151         203
# hdl_cholesterol                              52  ...          52          66
# ldl_cholesterol                             103  ...          90          97
# triglycerides                               104  ...         109         224
# glucose_fasting                              76  ...         117         138
# glucose_postprandial                        109  ...         175         191
# insulin_level                              4.49  ...        8.48       10.75
# hba1c                                      4.99  ...        6.84        7.23
# diabetes_risk_score                        30.0  ...        23.9        37.0
# diabetes_stage                      No Diabetes  ...      Type 2      Type 2
# diagnosed_diabetes                            0  ...           1           1
#
#                                        99992       99993         99994  \
# age                                       47          53            71
# gender                                Female        Male        Female
# ethnicity                              White       Black      Hispanic
# education_level                     Graduate  Highschool      Graduate
# income_level                          Middle      Middle  Lower-Middle
# employment_status                   Employed  Unemployed      Employed
# smoking_status                         Never     Current         Never
# alcohol_consumption_per_week               1           0             1
# physical_activity_minutes_per_week        94         179            82
# diet_score                               5.6         5.4           6.3
# sleep_hours_per_day                      6.0         6.1           6.9
# screen_time_hours_per_day                6.5         4.5           4.8
# family_history_diabetes                    0           0             0
# hypertension_history                       0           0             1
# cardiovascular_history                     0           0             0
# bmi                                     27.8        25.8          20.5
# waist_to_hip_ratio                      0.91        0.87          0.85
# systolic_bp                              110         122           132
# diastolic_bp                              76          93            75
# heart_rate                                68          71            60
# cholesterol_total                        206         177           141
# hdl_cholesterol                           48          47            48
# ldl_cholesterol                          140         109            57
# triglycerides                            163          97            30
# glucose_fasting                          125         129           115
# glucose_postprandial                     157         161           180
# insulin_level                           8.01        4.38          3.79
# hba1c                                   6.94        6.69          7.01
# diabetes_risk_score                     29.2        25.3          30.7
# diabetes_stage                        Type 2      Type 2        Type 2
# diagnosed_diabetes                         1           1             1
#
#                                            99995         99996         99997  \
# age                                           46            41            57
# gender                                      Male        Female        Female
# ethnicity                                  Other         White         Black
# education_level                         Graduate      Graduate     No formal
# income_level                        Upper-Middle        Middle  Upper-Middle
# employment_status                     Unemployed      Employed      Employed
# smoking_status                            Former         Never        Former
# alcohol_consumption_per_week                   1             3             4
# physical_activity_minutes_per_week           136            76           121
# diet_score                                   8.3           8.8           9.9
# sleep_hours_per_day                          6.4           6.8           5.0
# screen_time_hours_per_day                    4.5           4.8           6.1
# family_history_diabetes                        0             0             0
# hypertension_history                           0             0             0
# cardiovascular_history                         0             0             1
# bmi                                         29.8          26.5          25.6
# waist_to_hip_ratio                          0.93          0.86          0.83
# systolic_bp                                  126           130           107
# diastolic_bp                                  74            76            87
# heart_rate                                    63            57            69
# cholesterol_total                            227           207           189
# hdl_cholesterol                               45            55            50
# ldl_cholesterol                              150           123           111
# triglycerides                                116           146           184
# glucose_fasting                              113            96            93
# glucose_postprandial                         109           146           132
# insulin_level                              14.58          9.02          2.57
# hba1c                                       5.55          5.97          5.21
# diabetes_risk_score                         26.0          24.4          27.6
# diabetes_stage                      Pre-Diabetes  Pre-Diabetes   No Diabetes
# diagnosed_diabetes                             0             0             0
#
#                                            99998         99999
# age                                           47            52
# gender                                    Female        Female
# ethnicity                                  Black         White
# education_level                       Highschool  Postgraduate
# income_level                        Lower-Middle        Middle
# employment_status                        Retired      Employed
# smoking_status                             Never         Never
# alcohol_consumption_per_week                   3             1
# physical_activity_minutes_per_week            52           248
# diet_score                                   5.9           2.7
# sleep_hours_per_day                          6.7           5.4
# screen_time_hours_per_day                    0.5           5.5
# family_history_diabetes                        0             0
# hypertension_history                           1             0
# cardiovascular_history                         0             0
# bmi                                         26.8          30.3
# waist_to_hip_ratio                          0.89           1.0
# systolic_bp                                  115           109
# diastolic_bp                                  77            77
# heart_rate                                    58            55
# cholesterol_total                            173           238
# hdl_cholesterol                               68            31
# ldl_cholesterol                               91           183
# triglycerides                                116            87
# glucose_fasting                              106            91
# glucose_postprandial                         117           142
# insulin_level                               9.81         15.93
# hba1c                                       5.53          5.73
# diabetes_risk_score                         26.4          27.9
# diabetes_stage                      Pre-Diabetes  Pre-Diabetes
# diagnosed_diabetes                             0             0
#
# [31 rows x 100000 columns]

# %%
df.dtypes
# Out:
# age                                     int64
# gender                                 object
# ethnicity                              object
# education_level                        object
# income_level                           object
# employment_status                      object
# smoking_status                         object
# alcohol_consumption_per_week            int64
# physical_activity_minutes_per_week      int64
# diet_score                            float64
# sleep_hours_per_day                   float64
# screen_time_hours_per_day             float64
# family_history_diabetes                 int64
# hypertension_history                    int64
# cardiovascular_history                  int64
# bmi                                   float64
# waist_to_hip_ratio                    float64
# systolic_bp                             int64
# diastolic_bp                            int64
# heart_rate                              int64
# cholesterol_total                       int64
# hdl_cholesterol                         int64
# ldl_cholesterol                         int64
# triglycerides                           int64
# glucose_fasting                         int64
# glucose_postprandial                    int64
# insulin_level                         float64
# hba1c                                 float64
# diabetes_risk_score                   float64
# diabetes_stage                         object
# diagnosed_diabetes                      int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# age                                   0
# gender                                0
# ethnicity                             0
# education_level                       0
# income_level                          0
# employment_status                     0
# smoking_status                        0
# alcohol_consumption_per_week          0
# physical_activity_minutes_per_week    0
# diet_score                            0
# sleep_hours_per_day                   0
# screen_time_hours_per_day             0
# family_history_diabetes               0
# hypertension_history                  0
# cardiovascular_history                0
# bmi                                   0
# waist_to_hip_ratio                    0
# systolic_bp                           0
# diastolic_bp                          0
# heart_rate                            0
# cholesterol_total                     0
# hdl_cholesterol                       0
# ldl_cholesterol                       0
# triglycerides                         0
# glucose_fasting                       0
# glucose_postprandial                  0
# insulin_level                         0
# hba1c                                 0
# diabetes_risk_score                   0
# diabetes_stage                        0
# diagnosed_diabetes                    0
# dtype: int64

# %%
df.head()
# Out:
#    age  gender ethnicity education_level  income_level employment_status  \
# 0   58    Male     Asian      Highschool  Lower-Middle          Employed
# 1   48  Female     White      Highschool        Middle          Employed
# 2   60    Male  Hispanic      Highschool        Middle        Unemployed
# 3   74  Female     Black      Highschool           Low           Retired
# 4   46    Male     White        Graduate        Middle           Retired
#
#   smoking_status  alcohol_consumption_per_week  \
# 0          Never                             0
# 1         Former                             1
# 2          Never                             1
# 3          Never                             0
# 4          Never                             1
#
#    physical_activity_minutes_per_week  diet_score  ...  hdl_cholesterol  \
# 0                                 215         5.7  ...               41
# 1                                 143         6.7  ...               55
# 2                                  57         6.4  ...               66
# 3                                  49         3.4  ...               50
# 4                                 109         7.2  ...               52
#
#    ldl_cholesterol  triglycerides  glucose_fasting  glucose_postprandial  \
# 0              160            145              136                   236
# 1               50             30               93                   150
# 2               99             36              118                   195
# 3               79            140              139                   253
# 4              125            160              137                   184
#
#    insulin_level  hba1c  diabetes_risk_score  diabetes_stage  \
# 0           6.36   8.18                 29.6          Type 2
# 1           2.00   5.63                 23.0     No Diabetes
# 2           5.07   7.51                 44.7          Type 2
# 3           5.28   9.03                 38.2          Type 2
# 4          12.74   7.20                 23.5          Type 2
#
#    diagnosed_diabetes
# 0                   1
# 1                   0
# 2                   1
# 3                   1
# 4                   1
#
# [5 rows x 31 columns]

# %%
df.nunique()
# Out:
# age                                     73
# gender                                   3
# ethnicity                                5
# education_level                          4
# income_level                             5
# employment_status                        4
# smoking_status                           3
# alcohol_consumption_per_week            11
# physical_activity_minutes_per_week     620
# diet_score                             101
# sleep_hours_per_day                     71
# screen_time_hours_per_day              156
# family_history_diabetes                  2
# hypertension_history                     2
# cardiovascular_history                   2
# bmi                                    240
# waist_to_hip_ratio                      40
# systolic_bp                             86
# diastolic_bp                            60
# heart_rate                              64
# cholesterol_total                      210
# hdl_cholesterol                         79
# ldl_cholesterol                        190
# triglycerides                          262
# glucose_fasting                        109
# glucose_postprandial                   210
# insulin_level                         2350
# hba1c                                  548
# diabetes_risk_score                    569
# diabetes_stage                           5
# diagnosed_diabetes                       2
# dtype: int64

# %%
df.dtypes
# Out:
# age                                     int64
# gender                                 object
# ethnicity                              object
# education_level                        object
# income_level                           object
# employment_status                      object
# smoking_status                         object
# alcohol_consumption_per_week            int64
# physical_activity_minutes_per_week      int64
# diet_score                            float64
# sleep_hours_per_day                   float64
# screen_time_hours_per_day             float64
# family_history_diabetes                 int64
# hypertension_history                    int64
# cardiovascular_history                  int64
# bmi                                   float64
# waist_to_hip_ratio                    float64
# systolic_bp                             int64
# diastolic_bp                            int64
# heart_rate                              int64
# cholesterol_total                       int64
# hdl_cholesterol                         int64
# ldl_cholesterol                         int64
# triglycerides                           int64
# glucose_fasting                         int64
# glucose_postprandial                    int64
# insulin_level                         float64
# hba1c                                 float64
# diabetes_risk_score                   float64
# diabetes_stage                         object
# diagnosed_diabetes                      int64
# dtype: object

# %%
del df['diabetes_stage']
del df['diabetes_risk_score']

# %%
df.diagnosed_diabetes[df['diagnosed_diabetes']==0].value_counts()
# Out:
# diagnosed_diabetes
# 0    40002
# Name: count, dtype: int64

# %%
df.diagnosed_diabetes[df['diagnosed_diabetes']==1].value_counts()
# Out:
# diagnosed_diabetes
# 1    59998
# Name: count, dtype: int64

# %%
df.describe().round()
# Out:
#             age  alcohol_consumption_per_week  \
# count  100000.0                      100000.0
# mean       50.0                           2.0
# std        16.0                           1.0
# min        18.0                           0.0
# 25%        39.0                           1.0
# 50%        50.0                           2.0
# 75%        61.0                           3.0
# max        90.0                          10.0
#
#        physical_activity_minutes_per_week  diet_score  sleep_hours_per_day  \
# count                            100000.0    100000.0             100000.0
# mean                                119.0         6.0                  7.0
# std                                  84.0         2.0                  1.0
# min                                   0.0         0.0                  3.0
# 25%                                  57.0         5.0                  6.0
# 50%                                 100.0         6.0                  7.0
# 75%                                 160.0         7.0                  8.0
# max                                 833.0        10.0                 10.0
#
#        screen_time_hours_per_day  family_history_diabetes  \
# count                   100000.0                 100000.0
# mean                         6.0                      0.0
# std                          2.0                      0.0
# min                          0.0                      0.0
# 25%                          4.0                      0.0
# 50%                          6.0                      0.0
# 75%                          8.0                      0.0
# max                         17.0                      1.0
#
#        hypertension_history  cardiovascular_history       bmi  ...  \
# count              100000.0                100000.0  100000.0  ...
# mean                    0.0                     0.0      26.0  ...
# std                     0.0                     0.0       4.0  ...
# min                     0.0                     0.0      15.0  ...
# 25%                     0.0                     0.0      23.0  ...
# 50%                     0.0                     0.0      26.0  ...
# 75%                     1.0                     0.0      28.0  ...
# max                     1.0                     1.0      39.0  ...
#
#        heart_rate  cholesterol_total  hdl_cholesterol  ldl_cholesterol  \
# count    100000.0           100000.0         100000.0         100000.0
# mean         70.0              186.0             54.0            103.0
# std           8.0               32.0             10.0             33.0
# min          40.0              100.0             20.0             50.0
# 25%          64.0              164.0             47.0             78.0
# 50%          70.0              186.0             54.0            102.0
# 75%          75.0              208.0             61.0            126.0
# max         105.0              318.0             98.0            263.0
#
#        triglycerides  glucose_fasting  glucose_postprandial  insulin_level  \
# count       100000.0         100000.0              100000.0       100000.0
# mean           121.0            111.0                 160.0            9.0
# std             43.0             14.0                  31.0            5.0
# min             30.0             60.0                  70.0            2.0
# 25%             91.0            102.0                 139.0            5.0
# 50%            121.0            111.0                 160.0            9.0
# 75%            151.0            120.0                 181.0           12.0
# max            344.0            172.0                 287.0           32.0
#
#           hba1c  diagnosed_diabetes
# count  100000.0            100000.0
# mean        7.0                 1.0
# std         1.0                 0.0
# min         4.0                 0.0
# 25%         6.0                 0.0
# 50%         7.0                 1.0
# 75%         7.0                 1.0
# max        10.0                 1.0
#
# [8 rows x 23 columns]

# %%
from sklearn.model_selection import train_test_split

df_full_train, df_test = train_test_split(df, test_size=0.2, random_state=11)
df_train, df_val = train_test_split(df_full_train, test_size=0.25, random_state=11)

# %%
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

y_train = (df_train.diagnosed_diabetes).astype('int').values
y_val = (df_val.diagnosed_diabetes).astype('int').values
y_test = (df_test.diagnosed_diabetes).astype('int').values

del df_train['diagnosed_diabetes']
del df_val['diagnosed_diabetes']
del df_test['diagnosed_diabetes']

# %%
y_train
# Out:
# array([1, 1, 0, ..., 1, 1, 1])

# %%
df_train
# Out:
#        age  gender ethnicity education_level  income_level employment_status  \
# 0       35    Male     Black    Postgraduate        Middle           Retired
# 1       62  Female     White        Graduate        Middle          Employed
# 2       48    Male     White      Highschool  Lower-Middle          Employed
# 3       56  Female     White        Graduate  Upper-Middle          Employed
# 4       38    Male     White    Postgraduate  Upper-Middle          Employed
# ...    ...     ...       ...             ...           ...               ...
# 59995   51    Male     White      Highschool        Middle          Employed
# 59996   55    Male     White      Highschool        Middle           Retired
# 59997   69   Other     White        Graduate          High          Employed
# 59998   41    Male     White    Postgraduate        Middle        Unemployed
# 59999   38  Female     Black        Graduate  Upper-Middle          Employed
#
#       smoking_status  alcohol_consumption_per_week  \
# 0            Current                             4
# 1             Former                             2
# 2            Current                             3
# 3            Current                             1
# 4              Never                             3
# ...              ...                           ...
# 59995          Never                             1
# 59996        Current                             5
# 59997          Never                             1
# 59998        Current                             5
# 59999          Never                             1
#
#        physical_activity_minutes_per_week  diet_score  ...  diastolic_bp  \
# 0                                       7         7.0  ...            80
# 1                                     317         8.1  ...            86
# 2                                      78         1.6  ...            83
# 3                                      19         7.7  ...            71
# 4                                      78         7.6  ...            72
# ...                                   ...         ...  ...           ...
# 59995                                 154         6.7  ...            98
# 59996                                  72         5.6  ...            83
# 59997                                  18         3.7  ...            88
# 59998                                 174         4.2  ...            80
# 59999                                 173         3.8  ...            66
#
#        heart_rate  cholesterol_total  hdl_cholesterol  ldl_cholesterol  \
# 0              75                189               49              117
# 1              53                220               63              125
# 2              74                230               58              139
# 3              68                199               41              142
# 4              66                115               66               50
# ...           ...                ...              ...              ...
# 59995          66                220               43              165
# 59996          69                188               37              127
# 59997          79                205               54              128
# 59998          60                187               60               96
# 59999          81                223               55              139
#
#        triglycerides  glucose_fasting  glucose_postprandial  insulin_level  \
# 0                109              130                   173           3.55
# 1                 56              136                   241           2.00
# 2                169              121                   163          16.13
# 3                102              125                   234           3.53
# 4                165              143                   161           9.18
# ...              ...              ...                   ...            ...
# 59995             77               87                   122          10.06
# 59996            186              102                   137          18.25
# 59997             30              120                   207          11.15
# 59998             69              125                   203           2.07
# 59999            125              144                   200           9.73
#
#        hba1c
# 0       7.44
# 1       8.65
# 2       6.35
# 3       8.43
# 4       6.74
# ...      ...
# 59995   5.49
# 59996   6.17
# 59997   7.73
# 59998   7.48
# 59999   7.97
#
# [60000 rows x 28 columns]

# %% [markdown]
# ## Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.feature_extraction import DictVectorizer
from sklearn.metrics import roc_auc_score

from sklearn.tree import export_text

# %%
train_dicts = df_train.to_dict(orient='records')

dv = DictVectorizer(sparse=False)
X_train = dv.fit_transform(train_dicts)

dt = DecisionTreeClassifier(max_depth=6)
dt.fit(X_train, y_train)

val_dicts = df_val.to_dict(orient='records')
X_val = dv.transform(val_dicts)

y_pred = dt.predict_proba(X_val)[:, 1]
roc_auc_score(y_val, y_pred)
# Out:
# np.float64(0.9452078638350099)

# %%
print(export_text(dt, feature_names=list(dv.get_feature_names_out())))
# Out:
# |--- hba1c <= 6.49
# |   |--- glucose_fasting <= 125.50
# |   |   |--- family_history_diabetes <= 0.50
# |   |   |   |--- age <= 45.50
# |   |   |   |   |--- triglycerides <= 127.50
# |   |   |   |   |   |--- age <= 27.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- age >  27.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- triglycerides >  127.50
# |   |   |   |   |   |--- physical_activity_minutes_per_week <= 146.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- physical_activity_minutes_per_week >  146.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- age >  45.50
# |   |   |   |   |--- physical_activity_minutes_per_week <= 191.50
# |   |   |   |   |   |--- age <= 67.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- age >  67.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- physical_activity_minutes_per_week >  191.50
# |   |   |   |   |   |--- insulin_level <= 4.12
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- insulin_level >  4.12
# |   |   |   |   |   |   |--- class: 0
# |   |   |--- family_history_diabetes >  0.50
# |   |   |   |--- physical_activity_minutes_per_week <= 127.50
# |   |   |   |   |--- physical_activity_minutes_per_week <= 9.50
# |   |   |   |   |   |--- age <= 38.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- age >  38.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- physical_activity_minutes_per_week >  9.50
# |   |   |   |   |   |--- ldl_cholesterol <= 149.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- ldl_cholesterol >  149.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- physical_activity_minutes_per_week >  127.50
# |   |   |   |   |--- age <= 72.50
# |   |   |   |   |   |--- cholesterol_total <= 146.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- cholesterol_total >  146.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- age >  72.50
# |   |   |   |   |   |--- bmi <= 23.05
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- bmi >  23.05
# |   |   |   |   |   |   |--- class: 0
# |   |--- glucose_fasting >  125.50
# |   |   |--- class: 1
# |--- hba1c >  6.49
# |   |--- class: 1

# %%
scores = []

for depth in [2,4, 5, 6,10]:
    for s in [1, 5, 10, 15, 20, 500, 100, 200]:
        dt = DecisionTreeClassifier(max_depth=depth, min_samples_leaf=s)
        dt.fit(X_train, y_train)

        y_pred = dt.predict_proba(X_val)[:, 1]
        auc = roc_auc_score(y_val, y_pred)
        
        scores.append((depth, s, auc))

# %%
columns = ['max_depth', 'min_samples_leaf', 'auc']
df_scores = pd.DataFrame(scores, columns=columns)

# %%
df_scores_pivot = df_scores.pivot(index='min_samples_leaf', columns=['max_depth'], values=['auc'])
df_scores_pivot
# Out:
#                        auc
# max_depth               2         4         5         6         10
# min_samples_leaf
# 1                 0.935707  0.943936  0.944740  0.945208  0.940171
# 5                 0.935707  0.943936  0.944740  0.945208  0.942971
# 10                0.935707  0.943936  0.944740  0.945196  0.942949
# 15                0.935707  0.943936  0.944740  0.945196  0.942039
# 20                0.935707  0.943936  0.944740  0.945195  0.942985
# 100               0.935707  0.943936  0.944756  0.945157  0.943096
# 200               0.935707  0.943936  0.944453  0.944913  0.943198
# 500               0.935707  0.943936  0.944720  0.945276  0.944459

# %%
full_train_dicts = df_full_train.to_dict(orient='records')

dv = DictVectorizer(sparse=False)
X_full_train = dv.fit_transform(full_train_dicts)

dt = DecisionTreeClassifier(max_depth=5)
y_full_train= np.concatenate([y_train, y_val])
dt.fit(X_full_train, y_full_train)

test_dicts = df_test.to_dict(orient='records')
X_test = dv.transform(test_dicts)

y_pred = dt.predict_proba(X_test)[:, 1]
roc_auc_score(y_test, y_pred)
# Out:
# np.float64(0.5659172968824796)

# %% [markdown]
# ## RandomForest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
scores = []

for d in [5, 10, 15]:
    for n in range(10, 101, 10):
        rf = RandomForestClassifier(n_estimators=n,
                                    max_depth=d,
                                    random_state=1)
        rf.fit(X_train, y_train)

        y_pred = rf.predict_proba(X_val)[:, 1]
        auc = roc_auc_score(y_val, y_pred)

        scores.append((d, n, auc))

# %%
columns = ['max_depth', 'n_estimators', 'auc']
df_scores = pd.DataFrame(scores, columns=columns)

# %%
for d in [5, 10, 15]:
    df_subset = df_scores[df_scores.max_depth == d]
    
    plt.plot(df_subset.n_estimators, df_subset.auc,
             label='max_depth=%d' % d)

plt.legend()

# %%
max_depth = 10
scores = []

for s in [1, 3, 5, 10, 50]:
    for n in range(10, 101, 10):
        rf = RandomForestClassifier(n_estimators=n,
                                    max_depth=max_depth,
                                    min_samples_leaf=s,
                                    random_state=1)
        rf.fit(X_train, y_train)

        y_pred = rf.predict_proba(X_val)[:, 1]
        auc = roc_auc_score(y_val, y_pred)

        scores.append((s, n, auc))

# %%
columns = ['min_samples_leaf', 'n_estimators', 'auc']
df_scores = pd.DataFrame(scores, columns=columns)

# %%
colors = ['black', 'blue', 'orange', 'red', 'grey']
values = [1, 3, 5, 10, 50]

for s, col in zip(values, colors):
    df_subset = df_scores[df_scores.min_samples_leaf == s]
    
    plt.plot(df_subset.n_estimators, df_subset.auc,
             color=col,
             label='min_samples_leaf=%d' % s)

plt.legend()

# %%
min_samples_leaf = 5
rf = RandomForestClassifier(n_estimators=80,
                            max_depth=10,
                            min_samples_leaf=5,
                            random_state=1)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=10, min_samples_leaf=5, n_estimators=80,
#                        random_state=1)

# %%
y_pred=rf.predict_proba(X_val)[:,1]
y_pred
# Out:
# array([0.98628633, 0.97789343, 0.18845548, ..., 0.34885455, 0.29738339,
#        0.96130744])

# %%
roc_auc_score(y_val,y_pred)
# Out:
# np.float64(0.9442353985439622)

# %%
min_samples_leaf = 5
rf = RandomForestClassifier(n_estimators=80,
                            max_depth=max_depth,
                            min_samples_leaf=min_samples_leaf,
                            random_state=1)
rf.fit(X_full_train, y_full_train)

# %%
y_pred=rf.predict_proba(X_test)[:,1]
y_pred

# %%
roc_auc_score(y_test,y_pred)

# %% [markdown]
# ## XG Boost

# %%
import xgboost as xgb

# %%
features = list(dv.get_feature_names_out())
dtrain = xgb.DMatrix(X_train, label=y_train, feature_names=features)
dval = xgb.DMatrix(X_val, feature_names=features)

# %%
xgb_params = {
    'eta': 0.3, 
    'max_depth': 10,
    'min_child_weight': 1,
    
    'objective': 'binary:logistic',
    'nthread': 8,
    
    'seed': 1,
    'verbosity': 1,
}

model = xgb.train(xgb_params, dtrain, num_boost_round=10)

# %%
y_pred = model.predict(dval)
y_pred
# Out:
# array([0.9815066 , 0.9815066 , 0.18939751, ..., 0.19419803, 0.16354534,
#        0.9815066 ], dtype=float32)

# %%
roc_auc_score(y_val, y_pred)
# Out:
# np.float64(0.944112572987449)

# %%
xgb_params = {
    'eta': 0.01, 
    'max_depth': 8,
    'min_child_weight': 10,
    
    'objective': 'binary:logistic',
    'eval_metric': 'auc',

    'nthread': 8,
    'seed': 1,
    'verbosity': 1,
}

model = xgb.train(xgb_params, dtrain, num_boost_round=150)

# %%
y_pred = model.predict(dval)
y_pred
# Out:
# array([0.91041523, 0.91041523, 0.25751227, ..., 0.3685587 , 0.30538833,
#        0.91041523], dtype=float32)

# %%
roc_auc_score(y_val, y_pred)
# Out:
# np.float64(0.9465002905112795)

# %%
dfulltrain = xgb.DMatrix(X_full_train, label=y_full_train, feature_names=features)
dtest = xgb.DMatrix(X_test, feature_names=features)

# %%
xgb_params = {
    'eta': 0.1, 
    'max_depth': 4,
    'min_child_weight': 5,
    
    'objective': 'binary:logistic',
    'eval_metric': 'auc',

    'nthread': 8,
    'seed': 1,
    'verbosity': 1,
}

model = xgb.train(xgb_params, dfulltrain, num_boost_round=150)

# %%
y_pred = model.predict(dtest)
y_pred

# %%
roc_auc_score(y_test, y_pred)

# %% [markdown]
# ## Cross-Validation

# %%
from sklearn.model_selection import KFold

# %%
kfold = KFold(n_splits=10, shuffle=True, random_state=1)

for train_idx, val_idx in kfold.split(df_full_train):
        df_train = df_full_train.iloc[train_idx]
        df_val = df_full_train.iloc[val_idx]

        y_train = (df_train.diagnosed_diabetes).astype('int').values
        y_val = (df_val.diagnosed_diabetes).astype('int').values

# %%
train_dicts = df_train.to_dict(orient='records')

dv = DictVectorizer(sparse=False)
X_train = dv.fit_transform(train_dicts)

dt = DecisionTreeClassifier(max_depth=6)
dt.fit(X_train, y_train)

val_dicts = df_val.to_dict(orient='records')
X_val = dv.transform(val_dicts)

y_pred = dt.predict_proba(X_val)[:, 1]
roc_auc_score(y_val, y_pred)
# Out:
# np.float64(0.9452078638350099)

# %%
test_dicts = df_test.to_dict(orient='records')
X_test = dv.transform(test_dicts)

y_pred = dt.predict_proba(X_test)[:, 1]
roc_auc_score(y_test, y_pred)
# Out:
# np.float64(0.945245670839663)

# %% [markdown]
# ## Final Model

# %%
df_full_train = df_full_train.reset_index(drop=True)
y_full_train = (df_full_train.diagnosed_diabetes).astype('int').values

del df_full_train['diagnosed_diabetes']

# %%
dicts_full_train = df_full_train.to_dict(orient='records')

dv = DictVectorizer(sparse=False)
X_full_train = dv.fit_transform(dicts_full_train)

dicts_test = df_test.to_dict(orient='records')
X_test = dv.transform(dicts_test)

# %%
features = list(dv.get_feature_names_out())
dfulltrain = xgb.DMatrix(X_full_train, label=y_full_train,
                    feature_names=features)

dtest = xgb.DMatrix(X_test, feature_names=features)

# %%
xgb_params = {
    'eta': 0.1, 
    'max_depth': 4,
    'min_child_weight': 5,
    
    'objective': 'binary:logistic',
    'eval_metric': 'auc',

    'nthread': 8,
    'seed': 1,
    'verbosity': 1,
}

model = xgb.train(xgb_params, dfulltrain, num_boost_round=150)

# %%
y_pred = model.predict(dtest)

# %%
roc_auc_score(y_test, y_pred)
# Out:
# np.float64(0.9460397657684695)
